# %%
import pandas as pd
data = pd.read_json('D:\BOM_AUTOMATION\outputs\prototype_result_page_0.json')
data
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\B'
# <>:2: SyntaxWarning: invalid escape sequence '\B'
# C:\temp\ipykernel_35352\3585027847.py:2: SyntaxWarning: invalid escape sequence '\B'
#   data = pd.read_json('D:\BOM_AUTOMATION\outputs\prototype_result_page_0.json')
#       file  page  dpi  image_width  image_height  total_candidates  \
# 0    H.pdf     0  300         4963          3509              1008
# 1    H.pdf     0  300         4963          3509              1008
# 2    H.pdf     0  300         4963          3509              1008
# 3    H.pdf     0  300         4963          3509              1008
# 4    H.pdf     0  300         4963          3509              1008
# ..     ...   ...  ...          ...           ...               ...
# 851  H.pdf     0  300         4963          3509              1008
# 852  H.pdf     0  300         4963          3509              1008
# 853  H.pdf     0  300         4963          3509              1008
# ...
